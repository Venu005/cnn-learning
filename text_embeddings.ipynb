# %% [markdown]
# <a href="https://colab.research.google.com/github/Venu005/cnn-learning/blob/main/text_embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyPDF2==3.0.1 pinecone-client
# Out:
# Requirement already satisfied: PyPDF2==3.0.1 in /usr/local/lib/python3.11/dist-packages (3.0.1)
# Requirement already satisfied: pinecone-client in /usr/local/lib/python3.11/dist-packages (6.0.0)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.11/dist-packages (from pinecone-client) (2025.1.31)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from pinecone-client) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from pinecone-client) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from pinecone-client) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pinecone-client) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.5.3->pinecone-client) (1.17.0)

# %%
# !pip install pinecone-client
# Out:
# Requirement already satisfied: pinecone-client in /usr/local/lib/python3.11/dist-packages (6.0.0)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.11/dist-packages (from pinecone-client) (2025.1.31)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from pinecone-client) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from pinecone-client) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from pinecone-client) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pinecone-client) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.5.3->pinecone-client) (1.17.0)

# %%
# !pip install python-dotenv==1.0.0
# Out:
# Collecting python-dotenv==1.0.0
#   Downloading python_dotenv-1.0.0-py3-none-any.whl.metadata (21 kB)
# Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0

# %%
from google import genai
from google.genai import types
import PyPDF2
from pinecone import Pinecone
import hashlib
import datetime
import time
import pprint

# %%
from google.colab import userdata
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
PINECONE_API = userdata.get('PINECONE_API')

# %%
INDEX_NAME = "resume-parser"
EMBED_MODEL = "text-embedding-004"
CHUNK_SIZE = 2000

# %%
client =  genai.Client(api_key= GOOGLE_API_KEY )
pc = Pinecone(api_key=  PINECONE_API )

# %% [markdown]
# # Don't run the below two cells everytime

# %%
if pc.has_index(INDEX_NAME):
    pc.delete_index(INDEX_NAME)
    time.sleep(5)

# %%
pc.create_index(
       name=INDEX_NAME,
        dimension=768,
        spec={
        "dimension": 768,
        "metric": "cosine",
        "serverless" : {
            "cloud": "aws",
            "region": "us-east-1",

        }

       }

)
time.sleep(10)

# %%
index =  pc.Index(INDEX_NAME)

# %%
def extract_from_pdf(pdf_path):
  with open(pdf_path,'rb') as pdf_file:
    pdf_reader = PyPDF2.PdfReader(pdf_file)
    num_pages = len(pdf_reader.pages)
    text = ""
    for page_num in range(num_pages):
      page =  pdf_reader.pages[page_num]
      text += page.extract_text()
    return text

# %%
def store_in_pinecone(user_email, fullText):
    # Split text into chunks
    chunks = [fullText[i:i+CHUNK_SIZE] for i in range(0, len(fullText), CHUNK_SIZE)]

    vectors = []
    for i, chunk in enumerate(chunks):
        # Get embedding - PROPERLY EXTRACT VALUES  # returns dict
        embedding_response = client.models.embed_content(
            model=EMBED_MODEL,
            contents=chunk
        )

        embedding = embedding_response.embeddings[0].values
        print("eR:")
        print(embedding_response)
        print ("e")
        print(embedding)
        vectors.append({
            "id": f"{user_email}-{i}",
            "values": embedding,  # Should be List[float]
            "metadata": {
                "text": chunk,
                "user_email": user_email,
            }
        })

    index.upsert(vectors=vectors)

# %%
def process_resume(pdf_path,user_email):
  fullText = extract_from_pdf(pdf_path)
  resume_id = hashlib.sha256(fullText.encode()).hexdigest()
  store_in_pinecone(user_email,fullText)

  return fullText

# %%
def analyseJobDes(job_desc, user_email):
    # Generate job description embedding
    jd_embedding_response = client.models.embed_content(
        model=EMBED_MODEL,
        contents=job_desc
    )
    jd_embedding = jd_embedding_response.embeddings[0].values
    # Query Pinecone with email filter
    results = index.query(
        vector=jd_embedding,
        filter={"user_email": {"$eq": user_email}},
        top_k=10,
        include_metadata=True
    )

    if not results['matches']:
        return {"error": "No resume found for this user"}

    # Calculate similarity metrics
    avg_score = sum(match['score'] for match in results['matches']) / len(results['matches'])
    max_score = max(match['score'] for match in results['matches'])

    # Extract resume content from matches
    resume_chunks = [match['metadata']['text'] for match in results['matches']]
    resume_context = "\n---\n".join(resume_chunks)

    # Generate AI analysis
    analysis_prompt = f"""Analyze this job description against the user's resume excerpts:

    Job Description:
    {job_desc}

    Resume Excerpts:
    {resume_context}

    Provide specific suggestions focusing on:
    1. Missing technical skills
    2. Keyword optimization
    3. Experience alignment
    4. Certification recommendations
    5. Project improvements"""

    analysis_response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents= analysis_prompt
    ).text

    # Extract missing skills
    skill_prompt = f"""Identify missing technical skills from the resume compared to the job description:

    Job Description: {job_desc}
    Resume Excerpts: {resume_context}

    Output format: Missing: skill1, skill2, ..."""

    missing_skills = client.models.generate_content(
        model="gemini-2.0-flash",
        contents= skill_prompt
    ).text
    # Parse missing skills
    missing_list = []
    if "Missing:" in missing_skills:
        missing_list = [s.strip() for s in missing_skills.split("Missing:")[1].split(",")]

    return {
        "user_email": user_email,
        "similarity": {
            "average": round(avg_score, 2),
            "highest": round(max_score, 2)
        },
        "missing_skills": missing_list,
        "analysis": analysis_response,
        "top_matches": [
            {
                "text": match['metadata']['text'][:200] + "...",
                "score": round(match['score'], 2)
            } for match in results['matches']
        ]
    }

# %%
user_email =  "nagakushal10@gmail.com"

# %%
fullText = process_resume('Resume.pdf',user_email)
# Out:
# eR:
# embeddings=[ContentEmbedding(values=[0.004246525, -0.0113861, -0.051043175, 0.03900643, 0.07863846, 0.014029296, 0.028906835, -0.010667327, -0.010667593, -0.008460534, -0.0054368535, 0.016598338, 0.057275373, -0.010576915, 0.009261845, -0.024698775, 0.03758644, 0.05286926, -0.04396475, -0.04815396, -0.01858587, -0.051515087, 0.0067488747, 0.013240105, 0.016809376, -0.041073114, 0.002764179, -0.03943473, -0.026730448, 0.037410058, 0.032409053, 0.025968557, -0.035296816, 0.0033219312, -0.015106144, 0.04672577, 0.0128762955, 0.01653516, 0.030106183, -0.05476039, -0.005050315, -0.01970379, -0.041568775, 0.035199165, 0.019434143, -0.04663379, 0.00046043342, -0.028304178, -0.01993119, 0.04846088, 0.08646663, 0.012761189, -0.028440325, 0.010394405, -0.007615983, -0.03386494, -0.02443229, -0.04576662, -0.009775791, -0.00085134635, -0.010382255, -0.07057147, -0.02370606, -0.080261864, 0.0035022348, -0.049839865, -0.019895293, 0.036014073, -0.031895407, 0.020134863, -0.030631341, 0.033996664, -0.08175873, 0.05481616, -0.05840538, 0.0066573294, -0.014346795, -0.025765004, 0.04578168, 0.013918458, -0.077565394, 0.020678395, 0.028747307, -0.0034705817, -0.0054108724, 0.0037793936, 0.008631679, -0.061009414, 0.02075073, -0.03880103, 0.08413184, -0.013835488, 0.022074794, -0.020496419, 0.06634049, -0.07188636, -0.0458276, -0.027847707, 0.05309927, 0.051236887, 0.019179028, 0.031215109, -0.019693777, 0.01920057, -0.034378376, -0.0014562384, -0.025597181, -0.04512298, -0
-0.03213625, -0.02372093, 0.019001817, 0.0058722706, -0.013827728, 0.00012051345, -0.051895104, -0.012879612, 0.014184728, -0.010407128, -0.0074157505, -0.014766625, 0.012283271, -0.0073044756, -0.013981494, 0.03684635, 0.02237155, -0.058324862, -0.025168873, 0.010605273, -0.06939819, -0.027890582, 0.01879593, 0.0608829, 0.038325984, -0.00089175464, 0.007 ...

# %%
job_desc = "A full-stack developer, fresher with experience and projects in reactjs and nodejs"

# %%
response = analyseJobDes(job_desc,user_email)

# %%
pprint.pprint(response)
# Out:
# {'analysis': "Okay, let's break down Naga Kushal Vankadara's resume and how it "
#              'aligns with the full-stack developer job description, along with '
#              'specific recommendations for improvement.\n'
#              '\n'
#              '**Overall Assessment:**\n'
#              '\n'
#              "Naga Kushal's resume shows good potential for a fresher "
#              'full-stack developer role focusing on ReactJS and NodeJS. He has '
#              'relevant project experience and internships, but there are areas '
#              'where he can significantly improve his presentation and skillset '
#              'to make a stronger impression.\n'
#              '\n'
#              '**1. Missing Technical Skills:**\n'
#              '\n'
#              '*   **Testing:** The resume mentions "thorough testing of LLMs," '
#              'which is great but lacks details about testing methodologies for '
#              'web applications. He should explicitly mention experience with '
#              'testing frameworks like Jest, Mocha, Cypress, or React Testing '
#              'Library. This is crucial for a full-stack developer.\n'
#              '*   **State Management (beyond `useState`):** While ReactJS is '
#              "mentioned, the resume doesn't highlight advanced state "
#              'management beyond simple `useState`.  Consider mentioning '
#              'experience with Redux, Zustand, or Context API (if applicable).\n'
#              "*   **CI/CD:** There's no mention of Continuous "
#              'Integration/Continuous Deployment (CI/CD) tools like Jenkins, '
#              'GitHub Actions, or GitLab CI. Even basic experience with these '
#              'tools can be a significant advantage.\n'
#              "*   **Cloud Platforms:** While Firebase is mentioned, there's no "
#              'explicit mention of experience with other popular cloud '
#              'platforms like AWS, Azure, or Google Cloud Platform (GCP). If '
#              'any projects have been deployed on these platforms, he should '
#              'highlight that.\n'
#              '*   **Security:** No direct mention of security best practices '
#              'or specific knowledge regarding vulnerabilities, '
#              'authentication/authorization protocols (OAuth, JWT), or secure '
#              'coding practices.\n'
#              '\n'
#              '**Suggestions:**\n'
#              '\n'
#              '*   Actively learn and work on projects that incorporate the '
#              'above skills.\n'
#              '*   Even a small project showcasing a simple CI/CD pipeline can '
#              'be valuable.\n'
#              '*   Consider a basic cloud certification (AWS Certified Cloud '
#              'Practitioner, Azure Fundamentals, Google Cloud Associate Cloud '
#              'Engineer) to demonstrate interest.\n'
#              '\n'
#              '**2. Keyword Optimization:**\n'
#              '\n'
#              '*   **"Full-Stack Developer" needs to be prominent:** It\'s in '
#              'the profile, but should be more heavily emphasized throughout '
#              'the resume, specifically when describing roles. Instead of '
#              '"Backend Development Intern", it can be "Full Stack Development '
#              'Intern, focusing on Backend."\n'
#              '*   **Specificity is Key:**\n'
#              '    *   Instead of "Various other frameworks" under Front-end '
#              "development, list them. Even if it's just a few more (e.g., "
#              "Material UI, Ant Design), it's better than being vague.\n"
#              '    *   Instead of "Data structures and algorithms," mention '
#              'specific data structures he\'s proficient with (e.g., "Arrays, '
#              'Linked Lists, Trees, Graphs, Hash Tables").\n'
#              '*   **Industry Jargon:**  Sprinkle in relevant industry keywords '
#              'that recruiters often search for.  Examples:\n'
#              '    *   "Agile development"\n'
#              '    *   "RESTful APIs"\n'
#              '    *   "Microservices" (if applicable)\n'
#              '    *   "Version control" (Git is mentioned, but emphasize its '
#              'role)\n'
#              '    *   "Code reviews" (if he participated in them)\n'
#              '*   **Quantifiable Results:**  Where possible, quantify the '
#              'impact of his work.  For example, instead of "improve '
#              'application performance," try "improved application performance '
#              'by 15% by optimizing database queries."\n'
#              '\n'
#              '**Suggestions:**\n'
#              '\n'
#              '*   Review the job description carefully and identify the key '
#              'skills and technologies they are looking for. Make sure those '
#              'keywords are prominently featured in your resume, assuming you '
#              'have experience with them.\n'
#              '*   Use online tools like Jobscan to analyze your resume against '
#              'the job description and identify missing keywords.\n'
#              '\n'
#              '**3. Experience Alignment:**\n'
#              '\n'
#              '*   **NADevs Full Stack Web Developer Intern:**  This is listed '
#              'as "Present."  If it\'s a substantial internship, make sure to '
#              'provide concrete details about the technologies used and the '
#              'contributions made. This section should be as detailed as the '
#              'other work experiences.\n'
#              '*   **Freelancer (Outlier AI):** While interesting, this '
#              'experience might not be directly relevant to a full-stack '
#              'developer role. He should focus on highlighting the skills '
#              'learned during this role that *are* transferable. For example, '
#              '"Managed diverse client projects from inception to completion, '
#              'ensuring timely delivery and exceeding expectations.  Utilized '
#              'strong communication and project management skills." He can also '
#              'mention how the prompt engineering skills can translate to '
#              'creating good user interfaces, which relies on good user '
#              'experience.\n'
#              '*   **Connect Project Experience to Job Requirements:**  Clearly '
#              'explain how each project relates to the skills mentioned in the '
#              'job description.  For example, for Authify, he can mention that '
#              'it demonstrates experience with user authentication and '
#              'authorization, which is a crucial aspect of full-stack '
#              'development.\n'
#              '\n'
#              '**Suggestions:**\n'
#              '\n'
#              '*   Tailor your resume to each job application.  If a particular '
#              "experience isn't relevant, either omit it or focus on the "
#              'transferable skills.\n'
#              '*   For each experience, use action verbs to describe your '
#              'accomplishments and quantify your results whenever possible.\n'
#              '\n'
#              '**4. Certification Recommendations:**\n'
#              '\n'
#              '*   **Complete Coding Ninjas ReactJS certificate:** He has an '
#              '"Advance Front-end with ReactJS" certification. This needs to be '
#              "finished if it isn't already.\n"
#              '*   **Cloud Certification (AWS, Azure, GCP):**  A basic '
#              'certification demonstrates a commitment to learning and a '
#              'willingness to work with cloud technologies. The "Cloud '
#              'Practitioner" level certifications are a good starting point.\n'
#              "*   **Security Certification (Optional):**  If he's interested "
#              'in security, a basic certification like CompTIA Security+ could '
#              'be beneficial.\n'
#              '*   **Database Certification (Optional):** Depending on the '
#              'specific databases he is working with, a vendor-specific '
#              'certification (e.g., MongoDB Certified Developer) could add '
#              'value.\n'
#              '\n'
#              '**Suggestions:**\n'
#              '\n'
#              '*   Prioritize certifications that align with the job '
#              'requirements and his career goals.\n'
#              '*   Focus on certifications that demonstrate practical skills '
#              'and knowledge.\n'
#              '\n'
#              '**5. Project Improvements:**\n'
#              '\n'
#              '*   **GitHub Links:**  Include links to the GitHub repositories '
#              'for each project. This allows recruiters to review the code and '
#              'assess coding skills.\n'
#              '*   **Live Demos:**  If possible, host the projects online and '
#              'include links to the live demos. This shows that he can deploy '
#              'and maintain web applications.\n'
#              '*   **Expand Project Descriptions:** Add more detail to each '
#              'project description, including:\n'
#              '    *   The problem the project was trying to solve.\n'
#              '    *   The technologies used and why.\n'
#              '    *   The key features of the project.\n'
#              '    *   The challenges he faced and how he overcame them.\n'
#              '    *   Any lessons learned.\n'
#              '*   **Showcase Code Quality:**  Focus on writing clean, '
#              'well-documented code.  Use consistent coding style and follow '
#              'best practices.\n'
#              '*   **"WearCraft" specifics:** Adding to the "added some sweet '
#              'motion effects with Framer motion," he can mention which framer '
#              'motions he added. Recruiters are not technical experts, and will '
#              'only scan your resume for keywords that are in the job '
#              'description.\n'
#              '*   **Deployment:** Mention how he deployed the project, e.g., '
#              'Netlify, Vercel, Heroku.\n'
#              '\n'
#              '**Suggestions:**\n'
#              '\n'
#              '*   Treat your projects as a portfolio showcasing your skills '
#              'and experience.\n'
#              "*   Focus on quality over quantity.  It's better to have a few "
#              'well-developed projects than many incomplete or poorly coded '
#              'ones.\n'
#              '\n'
#              '**Revised Resume Excerpt Ideas (Illustrative):**\n'
#              '\n'
#              '*   **Skills:**  "Front-end Development: HTML5, CSS3, JavaScript '
#              '(ES6+), ReactJS, Redux (or Zustand), Material UI, Ant Design"\n'
#              '*   **Authify:** "Built a MERN-based email verification and '
#              'login template with MAIL TRAP integration for seamless '
#              'authentication, demonstrating experience with user '
#              'authentication and authorization. Implemented RESTful APIs using '
#              'ExpressJS. Deployed on Heroku. [GitHub Link]"\n'
#              '*   **Work Experience:** "NADevs, Full Stack Web Developer '
#              'Intern (Present): Developed and maintained web applications '
#              'using ReactJS, NodeJS, and MongoDB. Implemented new features, '
#              'fixed bugs, and improved application performance. Participated '
#              'in code reviews and collaborated with a team of developers using '
#              'Agile methodologies."\n'
#              '\n'
#              'By implementing these suggestions, Naga Kushal can significantly '
#              'strengthen his resume and increase his chances of landing a '
#              'full-stack developer role. Good luck!\n',
#  'missing_skills': ['None'],
#  'similarity': {'average': 0.65, 'highest': 0.68},
#  'top_matches': [{'score': 0.68,
#                   'text': 'NAGA KUSHAL VANKADARA\n'
#                           'Kurnool, Andhra Pradesh, India '
#                           'nagakushal10@gmail.com 9392684533\n'
#                           'www.linkedin.com/in/naga-kushal-vankadara-0559b1248 '
#                           'nagakushal786\n'
#                           'Proﬁle\n'
#                           'Full stack developer, Competitive progra...'},
#                  {'score': 0.62,
#                   'text': 's, and gave it a sleek look with TailwindCSS.\n'
#                           'Easy-Learn July 2024 - August 2024\n'
#                           "•Built an E-learning website 'Easy Learn' using "
#                           'ReactJS with robust error handling.\n'
#                           '•The platform offers personalized l...'}],
#  'user_email': 'nagakushal10@gmail.com'}
